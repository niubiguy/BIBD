# %% [markdown]
# ÍNDICE DE PRECIOS DE LA VIVIENDA
# ================================

# %% [markdown]
# <!--NAVIGATION-->
# <p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/01.01-Getting-Started-with-Python-and-Jupyter-Notebooks.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # 1.1 Instalacion de paquete Pandas-Profiling

# %% [markdown]
# El objetivo principal de pandas-profiling es proporcionar una experiencia de análisis de datos exploratorios (EDA) de una línea en una solución consistente y rápida

# %%
# !pip install pandas-profiling[notebook]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.0 MB/s eta 0:00:00
# ...

# %%
#Importando paquetes y librerías
from pandas_profiling import ProfileReport
import pandas as pd
import numpy as np

# data
df=pd.read_csv('/content/drive/MyDrive/CURSO-BD ANALITYCS/SEMANA 2/HPI_master.csv')

# %%
df
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 121467  developmental  purchase-only  quarterly             Puerto Rico
# 121468  developmental  purchase-only  quarterly             Puerto Rico
# 121469  developmental  purchase-only  quarterly             Puerto Rico
# 121470  developmental  purchase-only  quarterly             Puerto Rico
# 121471  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %%
# Ejecutamos nuestro reporte!
profile = ProfileReport(df, title="Pandas Profiling Report")
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.
